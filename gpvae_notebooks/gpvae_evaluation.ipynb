# %% [markdown]
# # HMNIST

# %%
import numpy as np
import sys
sys.path.append('..')
from imputegap.recovery.manager import TimeSeries
from imputegap.algorithms.gp_vae import gp_vae


# initialize the time series object
ts = TimeSeries()

validation_split = 60000
seq_length = 10
nbr_features = 784
validation_idx = validation_split*seq_length

# model folder
model_folder = '/home/kaeslin/Downloads/hmnist_trained'
# model_folder = '../external/models/251113_reproduce_hmnist'


hmnist_miss_val = np.load("../external/datasets/hmnist/x_miss_nan.npy")[:,validation_idx:]

# load and normalize the dataset
ts.import_matrix(hmnist_miss_val)

hmnist_full_val_gt = np.load("../external/datasets/hmnist/x_full.npy")[:,validation_idx:]

ground_truth = hmnist_full_val_gt.T.reshape(-1,seq_length,nbr_features)

y_val = np.load('../external/hmnist/hmnist_mnar.npz')['y_test']

try:
  ts_m_imputed, extras = gp_vae(ts.data, 
                        "../imputegap/wrapper/AlgoPython/GPVAE/config_gpvae_hmnist.yaml", 
                        model_folder,
                        ground_truth=ground_truth,
                        return_no_gt_imputation=True,
                        y_val=y_val,
                        verbose=False)
  print(extras)
finally:
  ts=None
  hmnist_miss_val = None
  hmnist_full_val_gt = None
# Out:
# Found config file in the checkpoints folder, it is going to be used instead of the one provided as config_yaml_path folder config_gpvae_hmnist.yaml
# 2026-01-17 11:48:47.593689: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:48:47.734851: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:48:47.737458: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:48:47.740575: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:48:47.742821: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:48:47.744839: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:48:47.885294: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:48:47.886687: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:48:47.887845: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:48:47.889120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2605 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Checkpoint successfully restored.
# Imputing progress:   0%|          | 0/157 [00:00<?, ?it/s]2026-01-17 11:48:48.743162: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2026-01-17 11:48:49.130380: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-17 11:48:49.130946: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-17 11:48:49.656186: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# Imputing progress: 100%|██████████| 157/157 [00:19<00:00,  8.23it/s]
# 100%|██████████| 157/157 [00:52<00:00,  2.99it/s]
# /home/kaeslin/miniconda3/envs/impute_gap/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# {'recov_no_gt': array([[9.91467264e-19, 5.33491501e-18, 2.63606500e-16, ...,
#         9.78644075e-12, 4.20501342e-11, 4.99353926e-11],
#        [9.94012085e-19, 6.33926075e-18, 4.70248605e-16, ...,
#         3.53100600e-12, 3.50453208e-11, 3.74772852e-11],
#        [8.96759241e-18, 4.04588497e-17, 1.52869097e-15, ...,
#         6.61994244e-12, 2.59588670e-11, 2.15032991e-11],
#        ...,
#        [2.08553574e-18, 1.02829643e-17, 3.87242658e-16, ...,
#         2.80193251e-12, 2.26223849e-11, 4.74352259e-11],
#        [1.91700381e-17, 9.13306790e-17, 2.23971097e-15, ...,
#         5.83454032e-12, 2.59800150e-11, 2.02550338e-11],
#        [1.14204336e-17, 4.26706711e-17, 9.19642094e-16, ...,
#         1.12665736e-11, 8.31765004e-11, 8.11896106e-11]], dtype=float32), 'evaluation_metrics': {'nll': 0.35092675802618684, 'mse': 0.11090976572234928, 'auroc': 0.9587696830686049, 'auprc': 0.8096611714973022}}

# %% [markdown]
# # SPRITES

# %%
import numpy as np
import sys
sys.path.append('..')
from imputegap.recovery.manager import TimeSeries
from imputegap.algorithms.gp_vae import gp_vae


# initialize the time series object
ts = TimeSeries()

validation_split = 9000
seq_length = 8
nbr_features = 12288
validation_idx = validation_split*seq_length

# model folder
model_folder = '/home/kaeslin/Downloads/sprites_trained'
# model_folder = '../external/models/251114_reproduce_sprites'

sprites_miss_val = np.load("../external/datasets/sprites/x_miss_nan.npy")[:,validation_idx:]

# load and normalize the dataset
ts.import_matrix(sprites_miss_val)

sprites_full_val_gt = np.load("../external/datasets/sprites/x_full.npy")[:,validation_idx:]

ground_truth = sprites_full_val_gt.T.reshape(-1,seq_length,nbr_features)

print(ts.data.shape)
try:
  ts_m_imputed, extras = gp_vae(ts.data, 
                        "../imputegap/wrapper/AlgoPython/GPVAE/config_gpvae_sprites.yaml", 
                        model_folder,
                        ground_truth=ground_truth,
                        return_no_gt_imputation=True,
                        inference_batch_size=16,
                        verbose=False)
  print(extras)
finally:
  ts=None
  sprites_miss_val = None
  sprites_full_val_gt = None
# Out:
# 2026-01-17 12:01:52.833854: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-17 12:01:52.898000: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-17 12:01:52.898804: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-17 12:01:52.954859: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-17 12:01:54.210213: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (12288, 21312)
# Found config file in the checkpoints folder, it is going to be used instead of the one provided as config_yaml_path folder config_gpvae_sprites.yaml
# 2026-01-17 12:02:13.393904: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 12:02:13.561596: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 12:02:13.564508: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 12:02:13.573456: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 12:02:13.576094: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 12:02:13.578453: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 12:02:13.772456: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 12:02:13.774222: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 12:02:13.775478: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 12:02:13.776834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2605 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Checkpoint successfully restored.
# Imputing progress:   0%|          | 0/167 [00:00<?, ?it/s]2026-01-17 12:02:15.375605: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2026-01-17 12:02:15.739622: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-17 12:02:15.739676: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-17 12:02:16.163732: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-17 12:02:16.376051: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# Imputing progress:  99%|█████████▉| 165/167 [00:16<00:00, 12.00it/s]2026-01-17 12:02:30.850936: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-17 12:02:31.033525: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-17 12:02:31.144253: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# Imputing progress: 100%|██████████| 167/167 [00:16<00:00,  9.83it/s]
# 100%|██████████| 167/167 [00:45<00:00,  3.64it/s]
# {'recov_no_gt': array([[ 7.6861010e-04,  9.9123653e-04,  8.3861337e-04, ...,
#          3.8671430e-04,  6.8237522e-04, -2.9859209e-04],
#        [ 1.1882482e-03,  2.5150653e-03,  4.4363039e-03, ...,
#          2.2632519e-03,  2.1890744e-03,  2.3916808e-03],
#        [-4.5534852e-04, -2.8614345e-04,  4.9739220e-04, ...,
#         -4.6334520e-05, -1.3247214e-04, -1.3226358e-04],
#        ...,
#        [ 2.0972341e-03,  1.3935610e-03, -2.3734017e-04, ...,
#          2.5800541e-03,  2.5483256e-03,  1.9478891e-03],
#        [ 1.2970379e-03,  7.1800896e-04,  7.2835619e-04, ...,
#          7.6298986e-04,  7.7684934e-04,  1.1472565e-03],
#        [-8.4904575e-05,  1.5624144e-04, -3.0280012e-04, ...,
#         -6.9692003e-05, -5.9027370e-06,  5.2063225e-04]], dtype=float32), 'evaluation_metrics': {'nll': 0.9200334943877392, 'mse': 0.0019548766377034624}}

# %% [markdown]
# # Physionet

# %%
import numpy as np
import sys
sys.path.append('..')
from imputegap.recovery.manager import TimeSeries
from imputegap.algorithms.gp_vae import gp_vae

# initialize the time series object
ts = TimeSeries()
ts_gt = TimeSeries()

validation_split = 3997
seq_length = 48
nbr_features = 35
validation_idx = validation_split*seq_length

# model folder
model_folder = '/home/kaeslin/Downloads/physionet_trained'
# model_folder = '../external/models/251123_reproduce_physionet'

ts.load_series("../external/datasets/physionet/x_miss_nan.txt")

ts_gt.load_series("../external/datasets/physionet/x_full.txt")

ground_truth = ts_gt.data[:, :validation_idx].T.reshape(-1,seq_length,nbr_features)

y_val = np.load('../external/physionet/physionet.npz')['y_train']

try:
  ts_m_imputed, extras = gp_vae(ts.data[:, :validation_idx], 
                        "../imputegap/wrapper/AlgoPython/GPVAE/config_gpvae_physionet.yaml", 
                        model_folder,
                        ground_truth=ground_truth,
                        return_no_gt_imputation=True,
                        y_val=y_val,
                        verbose=False)
  print(extras)
finally:
  ts=None
  physionet_miss_val = None
  physionet_full_val_gt = None
# Out:
# 2026-01-17 11:43:38.747656: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-17 11:43:38.798313: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-17 11:43:38.799003: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-17 11:43:38.837733: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-17 11:43:40.029244: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (SYS) The dataset is loaded from ../external/datasets/physionet/merged/x_miss_nan.txt
#
#
# (SYS) The dataset is loaded from ../external/datasets/physionet/merged/x_full.txt
#
# Found config file in the checkpoints folder, it is going to be used instead of the one provided as config_yaml_path folder config_gpvae_physionet.yaml
# 2026-01-17 11:44:03.300737: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:44:03.335323: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:44:03.338062: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:44:03.340779: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:44:03.342909: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:44:03.344850: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:44:03.474528: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:44:03.475659: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:44:03.476663: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-17 11:44:03.477627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2605 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Checkpoint successfully restored.
# Imputing progress:   0%|          | 0/32 [00:00<?, ?it/s]2026-01-17 11:44:04.176293: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# Imputing progress: 100%|██████████| 32/32 [00:06<00:00,  4.85it/s]
# 100%|██████████| 32/32 [00:17<00:00,  1.83it/s]
# /home/kaeslin/miniconda3/envs/impute_gap/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# {'recov_no_gt': array([[ 0.5938084 ,  0.64163357,  0.67906475, ...,  0.76164144,
#          0.6890422 ,  0.598177  ],
#        [ 0.20635587,  0.26724336,  0.3393055 , ..., -0.23922177,
#         -0.26698068, -0.30244496],
#        [ 0.15770647,  0.16501662,  0.17067078, ...,  0.05641285,
#          0.04030632,  0.02792778],
#        ...,
#        [ 0.76245433,  0.8312701 ,  0.88908654, ...,  0.40994024,
#          0.3801521 ,  0.33573794],
#        [-0.27697483, -0.28437552, -0.3001123 , ..., -0.373044  ,
#         -0.36474136, -0.35068694],
#        [-0.16057971, -0.16030386, -0.16704415, ..., -0.11169228,
#         -0.10760874, -0.10530597]], dtype=float32), 'evaluation_metrics': {'nll': 1.0058540784386796, 'mse': 0.13752158433505637, 'auroc': 0.7292882147024504, 'auprc': 0.34460859789719306}}
