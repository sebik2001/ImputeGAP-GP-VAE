# %% [markdown]
# # HMNIST

# %%
import numpy as np
import sys
sys.path.append('..')
from imputegap.recovery.manager import TimeSeries
from imputegap.algorithms.gp_vae import gp_vae


# initialize the time series object
ts = TimeSeries()

validation_split = 60000
seq_length = 10
nbr_features = 784
validation_idx = validation_split*seq_length

# model folder
model_folder = '/home/kaeslin/Downloads/hmnist_trained'
# model_folder = '../external/models/251113_reproduce_hmnist'


hmnist_miss_val = np.load("../external/datasets/hmnist/x_miss_nan.npy")[:,validation_idx:]

# load and normalize the dataset
ts.import_matrix(hmnist_miss_val)

hmnist_full_val_gt = np.load("../external/datasets/hmnist/x_full.npy")[:,validation_idx:]

ground_truth = hmnist_full_val_gt.T.reshape(-1,seq_length,nbr_features)

y_val = np.load('../external/hmnist/hmnist_mnar.npz')['y_test']

try:
  ts_m_imputed, ts_m_imputed_no_gt, results = gp_vae(ts.data, 
                        "../imputegap/wrapper/AlgoPython/GPVAE/config_gpvae_hmnist.yaml", 
                        model_folder,
                        ground_truth=ground_truth,
                        return_no_gt_imputation=True,
                        y_val=y_val,
                        verbose=False)
  print(results)
finally:
  ts=None
  hmnist_miss_val = None
  hmnist_full_val_gt = None
# Out:
# 2026-01-12 13:06:52.822318: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-12 13:06:52.846173: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-12 13:06:52.846209: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-12 13:06:52.860368: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-12 13:06:54.117856: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-01-12 13:07:03.537220: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 13:07:03.624154: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 13:07:03.626535: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 13:07:03.629923: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 13:07:03.632420: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 13:07:03.634937: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 13:07:03.791966: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 13:07:03.793159: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 13:07:03.794657: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 13:07:03.795675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2605 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Checkpoint successfully restored.
# Imputing progress:   0%|          | 0/157 [00:00<?, ?it/s]2026-01-12 13:07:04.555770: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2026-01-12 13:07:04.820025: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-12 13:07:04.820086: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-12 13:07:05.335645: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# Imputing progress: 100%|██████████| 157/157 [00:19<00:00,  8.05it/s]
# Model evaluation...
# 100%|██████████| 157/157 [00:53<00:00,  2.91it/s]
# /home/kaeslin/miniconda3/envs/impute_gap/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# {'nll': 0.3506960811710295, 'mse': 0.11090976572234928, 'auroc': 0.9587696830686049, 'auprc': 0.8096611714973022}

# %% [markdown]
# # SPRITES

# %%
import numpy as np
import sys
sys.path.append('..')
from imputegap.recovery.manager import TimeSeries
from imputegap.algorithms.gp_vae import gp_vae


# initialize the time series object
ts = TimeSeries()

validation_split = 9000
seq_length = 8
nbr_features = 12288
validation_idx = validation_split*seq_length

# model folder
model_folder = '/home/kaeslin/Downloads/sprites_trained'
# model_folder = '../external/models/251114_reproduce_sprites'

sprites_miss_val = np.load("../external/datasets/sprites/x_miss_nan.npy")[:,validation_idx:]

# load and normalize the dataset
ts.import_matrix(sprites_miss_val)

sprites_full_val_gt = np.load("../external/datasets/sprites/x_full.npy")[:,validation_idx:]

ground_truth = sprites_full_val_gt.T.reshape(-1,seq_length,nbr_features)

print(ts.data.shape)
try:
  ts_m_imputed, ts_m_imputed_no_gt, results = gp_vae(ts.data, 
                        "../imputegap/wrapper/AlgoPython/GPVAE/config_gpvae_sprites.yaml", 
                        model_folder,
                        ground_truth=ground_truth,
                        return_no_gt_imputation=True,
                        verbose=False)
  print(results)
finally:
  ts=None
  sprites_miss_val = None
  sprites_full_val_gt = None
# Out:
# 2026-01-12 10:46:09.451345: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-12 10:46:09.510566: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-12 10:46:09.511300: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-12 10:46:09.564834: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-12 10:46:10.729410: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (12288, 21312)
# 2026-01-12 10:46:31.452399: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 10:46:31.648987: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 10:46:31.651826: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 10:46:31.663938: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 10:46:31.666392: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 10:46:31.668936: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 10:46:31.882490: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 10:46:31.884093: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 10:46:31.885404: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-12 10:46:31.886806: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2605 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Checkpoint successfully restored.
# Imputing progress:   0%|          | 0/167 [00:00<?, ?it/s]2026-01-12 10:46:33.549542: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2026-01-12 10:46:33.914280: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-12 10:46:33.914335: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-12 10:46:34.336758: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-12 10:46:34.548582: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# Imputing progress:  99%|█████████▉| 165/167 [00:17<00:00, 11.60it/s]2026-01-12 10:46:49.753963: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-12 10:46:49.936841: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-01-12 10:46:50.047739: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# Imputing progress: 100%|██████████| 167/167 [00:17<00:00,  9.41it/s]
# Model evaluation...
# binary: False
# 100%|██████████| 167/167 [00:47<00:00,  3.53it/s]
# NLL sum: 144565752.5
# MSE sum: 307171.84411621094
# n_missings: 157131063
# {'nll': 0.9200329313625276, 'mse': 0.0019548766377034624}

# %% [markdown]
# # Physionet

# %%
import numpy as np
import sys
sys.path.append('..')
from imputegap.recovery.manager import TimeSeries
from imputegap.algorithms.gp_vae import gp_vae

# initialize the time series object
ts = TimeSeries()
ts_gt = TimeSeries()

validation_split = 3997
seq_length = 48
nbr_features = 35
validation_idx = validation_split*seq_length

# model folder
# model_folder = '/home/kaeslin/Downloads/physionet_trained'
model_folder = '../external/models/251123_reproduce_physionet'

ts.load_series("../external/datasets/physionet/merged/x_miss_nan.txt")

ts_gt.load_series("../external/datasets/physionet/merged/x_full.txt")

ground_truth = ts_gt.data[:, :validation_idx].T.reshape(-1,seq_length,nbr_features)

y_val = np.load('../external/physionet/physionet.npz')['y_train']

try:
  ts_m_imputed, ts_m_imputed_no_gt, results = gp_vae(ts.data[:, :validation_idx], 
                        "../imputegap/wrapper/AlgoPython/GPVAE/config_gpvae_physionet.yaml", 
                        model_folder,
                        ground_truth=ground_truth,
                        return_no_gt_imputation=True,
                        y_val=y_val,
                        verbose=False)
  print(results)
finally:
  ts=None
  physionet_miss_val = None
  physionet_full_val_gt = None
# Out:
# (SYS) The dataset is loaded from ../external/datasets/physionet/merged/x_miss_nan.txt
#
#
# (SYS) The dataset is loaded from ../external/datasets/physionet/merged/x_full.txt
#
# Checkpoint successfully restored.
# Imputing progress: 100%|██████████| 32/32 [00:04<00:00,  6.55it/s]
# Model evaluation...
# binary: False
# 100%|██████████| 32/32 [00:14<00:00,  2.23it/s]
# /home/kaeslin/miniconda3/envs/impute_gap/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# NLL sum: 5545391.2890625
# MSE sum: 731399.6831054688
# n_missings: 5529826
# {'nll': 1.0028147882162115, 'mse': 0.13226450219328217, 'auroc': 0.7266945075641262, 'auprc': 0.3376810125153675}
